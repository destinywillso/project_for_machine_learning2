# %%
import kagglehub
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
import os
from torch.utils.data import Dataset, DataLoader
from PIL import Image
from torchvision import transforms
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models
from torchvision.models import resnet18, ResNet18_Weights
import requests
import json

# %%
path = kagglehub.dataset_download("uom190346a/sleep-health-and-lifestyle-dataset")
print("Path to dataset files:", path)
path2 = kagglehub.dataset_download("arsalanjamal002/student-sleep-patterns")
print("Path to dataset files:", path2)
# Out:
# Path to dataset files: C:\Users\destiny\.cache\kagglehub\datasets\uom190346a\sleep-health-and-lifestyle-dataset\versions\2
# Path to dataset files: C:\Users\destiny\.cache\kagglehub\datasets\arsalanjamal002\student-sleep-patterns\versions\1

# %%
path_image = "D:\dataset\dataset"
path_text = "D:\dataset\Sleep_health_and_lifestyle_dataset.csv"

# %%
path_new = "D:\dataset\student_sleep_patterns.csv"
data_text = pd.read_csv(path_text)
data_new = pd.read_csv(path_new)

# %%
data_text.columns = [col.strip().replace(" ", "_") for col in data_text.columns]

# %%
bp_split = data_text["Blood_Pressure"].str.split("/", expand=True)
data_text["Systolic_BP"] = bp_split[0].astype(float)
data_text["Diastolic_BP"] = bp_split[1].astype(float)
data_text.drop(columns=["Blood_Pressure"], inplace=True)

# %%
categorical_cols = ['Gender', 'Occupation', 'BMI_Category', 'Sleep_Disorder']
data_text_encoded = pd.get_dummies(data_text, columns=categorical_cols)

# %%
continuous_cols = ['Age', 'Sleep_Duration', 'Quality_of_Sleep',
                   'Physical_Activity_Level', 'Stress_Level',
                   'Heart_Rate', 'Daily_Steps', 'Systolic_BP', 'Diastolic_BP']

scaler = StandardScaler()
data_text_encoded[continuous_cols] = scaler.fit_transform(data_text_encoded[continuous_cols])

# %%
x = data_text_encoded.drop(columns=['Person_ID', 'Quality_of_Sleep'])
y = data_text_encoded['Quality_of_Sleep']
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42
)

# %%
model_text = RandomForestRegressor(n_estimators=100, random_state=42)
model_text.fit(X_train, y_train)
y_pred = model_text.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"MSE: {mse:.2f}")
print(f"R^2: {r2:.2f}")
# Out:
# MSE: 0.02
# R^2: 0.98

# %%
data_new = pd.get_dummies(data_new, columns=["Gender", "University_Year"], drop_first=False)
data_new = data_new.drop(columns=["Gender_Other"])
feature_new = ["Age", "Sleep_Duration", "Study_Hours", "Screen_Time",
                "Caffeine_Intake", "Physical_Activity",
                "Weekday_Sleep_Start", "Weekend_Sleep_Start",
                "Gender_Male", "Gender_Female",
                "University_Year_2nd Year", "University_Year_4th Year"]
x_new = data_new[feature_new]
y_new = data_new["Sleep_Quality"]

# %%
x_train_new, x_test_new, y_train_new, y_test_new = train_test_split(
    x, y, test_size=0.2, random_state=42
)
model_text.fit(x_train_new, y_train_new)
y_pred_new = model_text.predict(x_test_new)

mse_new = mean_squared_error(y_test_new, y_pred_new)
r2_new = r2_score(y_test_new, y_pred_new)

print(f"MSE: {mse_new:.2f}")
print(f"R^2: {r2_new:.2f}")
# Out:
# MSE: 0.02
# R^2: 0.98

# %%
transform = transforms.Compose([
    transforms.Resize((224, 224)),       
    transforms.ToTensor(),               
    transforms.Normalize([0.5,0.5,0.5], [0.5,0.5,0.5])  
])

# %%
class SleepPoseDataset(Dataset):
    def __init__(self, csv_file, image_dir, transform=None):
        self.data = pd.read_csv(csv_file)
        self.data.columns = [col.strip() for col in self.data.columns] 
        self.image_dir = image_dir
        self.transform = transform
        self.labels_cols = [col for col in self.data.columns if col != 'filename']  

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        img_name = self.data.iloc[idx]['filename']
        img_path = f"{self.image_dir}/{img_name}"
        image = Image.open(img_path).convert('RGB')
        
        label = int(self.data.iloc[idx][self.labels_cols].values.argmax())
        
        if self.transform:
            image = self.transform(image)
        return image, label

# %%
image_dir = r"D:\dataset\dataset"
csv_file = r"D:\dataset\dataset\classes.csv"

dataset = SleepPoseDataset(csv_file=csv_file, image_dir=image_dir, transform=transform)
dataloader = DataLoader(dataset, batch_size=32, shuffle=True)
df = pd.read_csv(csv_file)
print(df.columns)
# Out:
# Index(['filename', ' Back', ' Fetal', ' Side', ' Stomach'], dtype='object')

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

weights = ResNet18_Weights.DEFAULT 
model_image = resnet18(weights=weights)


num_features = model_image.fc.in_features
model_image.fc = nn.Linear(num_features, 4)

model_image = model_image.to(device)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model_image.parameters(), lr=1e-4)

# %%
num_epochs = 10

for epoch in range(num_epochs):
    model_image.train()
    running_loss = 0.0
    for images, labels in dataloader:
        images = images.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()
        outputs = model_image(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * images.size(0)

    epoch_loss = running_loss / len(dataset)
    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {epoch_loss:.4f}")
# Out:
# Epoch 1/10, Loss: 1.1729
# Epoch 2/10, Loss: 0.3068
# Epoch 3/10, Loss: 0.1019
# Epoch 4/10, Loss: 0.0402
# Epoch 5/10, Loss: 0.0196
# Epoch 6/10, Loss: 0.0117
# Epoch 7/10, Loss: 0.0109
# Epoch 8/10, Loss: 0.0090
# Epoch 9/10, Loss: 0.0064
# Epoch 10/10, Loss: 0.0053

# %%
torch.save(model_image.state_dict(), "sleep_pose_model.pth")

# %%
#Zhang, Y., Xiao, A., Zheng, T., Xiao, H., & Huang, R. (2022). The relationship between sleeping position and sleep quality: A flexible sensor-based study. Sensors, 22(16), 6220. https://doi.org/10.3390/s22166220

# %%
pose_weights = {
    "Back": 8,
    "Fetal": 6,
    "Side": 10,
    "Stomach": 5
}

image_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

def predict_sleep_score(user_input_1, user_input_2, image_path):
    table_input_1 = pd.DataFrame(user_input_1)
    table_input_1_encoded = pd.get_dummies(table_input_1)
    for col in X_train.columns:
        if col not in table_input_1_encoded.columns:
            table_input_1_encoded[col] = 0
    table_input_1_encoded = table_input_1_encoded[x_train.columns]
    score1 = model_text.predict(table_input_1_encoded)[0]
    score1 = np.clip(score1, 1, 10)

    table_input_2 = pd.DataFrame([user_input_2])
    table_input_2_encoded = pd.get_dummies(table_input_2)
    for col in x_train_new.columns:
        if col not in table_input_2_encoded.columns:
            table_input_2_encoded[col] = 0
    table_input_2_encoded = table_input_2_encoded[x_train_new.columns]
    score2 = model_text.predict(table_input_2_encoded)[0]
    score2 = np.clip(score2, 1, 10)

    image = Image.open(image_path).convert("RGB")
    image_tensor = image_transform(image).unsqueeze(0).to(device)

    model_image.eval()
    with torch.no_grad():
        output = model_image(image_tensor)
        pred_class_idx = torch.argmax(output, dim=1).item()

    classes = ["Back", "Fetal", "Side", "Stomach"]
    pose = classes[pred_class_idx]
    pose_score = pose_weights[pose]

    final_score = 0.4 * score1 + 0.4 * score2 + 0.2 * pose_score
    final_score = np.clip(final_score, 1, 10)

    return final_score, pose, score1, score2, pose_score

user_input = {
    "Gender": ["Male"],
    "Age": [24],
    "Occupation": ["Student"],
    "Sleep_Duration": [8],
    "Physical_Activity_Level": [80],
    "Stress_Level": [2],
    "BMI_Category": ["Normal"],
    "Systolic_BP": [126],
    "Diastolic_BP": [83],
    "Heart_Rate": [77],
    "Daily_Steps": [10000],
    "Sleep_Disorder": ["None"]
}

user_input2 = {
    "Age": 24,
    "Sleep_Duration": 8,
    "Study_Hours": 5,
    "Screen_Time": 5,
    "Caffeine_Intake": 0,
    "Physical_Activity": 80,
    "Weekday_Sleep_Start": 24.0,
    "Weekend_Sleep_Start": 0.5,
    "Gender_Male": 1,    # Male=1, Female=0
    "Gender_Female": 0,
    "University_Year_2nd Year": 1,
    "University_Year_3rd Year": 0,
    "University_Year_4th Year": 0
}

score, pose, score1, score2, pose_score = predict_sleep_score(
    user_input,
    user_input2,
    "D:/dataset/dataset/5_jpg.rf.e09af9909b48fda74463bf9316ee4255.jpg"
)

print(f"final_score: {score:.2f}, pose: {pose}, score1: {score1:.2f}, score2: {score2:.2f} pose_score: {pose_score}")
# Out:
# final_score: 3.06, pose: Side, score1: 1.23, score2: 1.41 pose_score: 10

# %%
url = "http://localhost:11434/v1/chat/completions"
api_key = "bba95d6173f544c381330c270b2111db.xl4EDRCCPqe0l54PJZY2NyWQ"

def clean_user_info(user_input_dict):
    lines = []
    for k, v in user_input_dict.items():
        value = v[0] if isinstance(v, list) else v
        lines.append(f"{k.replace('_',' ')}: {value}")
    return "\n  ".join(lines)

text1 = clean_user_info(user_input)
text2 = clean_user_info(user_input2)

prompt = f"""
System: You are a sleep health expert. Analyze the following user sleep data and provide a detailed evaluation.

User Sleep Analysis:
- Personal Information (Model 1):
  {text1}
- Personal Information (Model 2):
  {text2}
- Table-based predicted score (Model 1): {score1:.2f}
- Table-based predicted score (Model 2): {score2:.2f}
- Image-predicted sleep posture: {pose} (Posture score: {pose_score})
- Final combined sleep score: {score:.2f}

Please provide:
1. Advantages and disadvantages of the user's sleep posture and overall sleep quality
2. Comprehensive recommendations to improve sleep quality
"""

data = {
    "model": "llama3:latest",
    "messages": [{"role": "user", "content": prompt}],
    "temperature": 0.8
}

headers = {
    "Authorization": f"Bearer {api_key}",
    "Content-Type": "application/json"
}

response = requests.post(url, headers=headers, data=json.dumps(data))
result = response.json()

print(result["choices"][0]["message"]["content"])
# Out:
# Based on the provided data, I'll analyze the user's sleep posture and overall sleep quality, and then offer comprehensive recommendations to improve their sleep quality.
#
# **Sleep Posture Analysis:**
# The user's sleep posture is classified as Side (Posture score: 10), which means they are sleeping on their side with a good alignment of their body. This is considered an ideal sleep posture, as it allows for proper spinal alignment, reduces pressure on joints, and promotes better breathing.
#
# Advantages:
#
# * Reduced risk of back pain and discomfort
# * Improved respiratory function due to reduced pressure on the chest and lungs
# * Potential benefits for digestion and gut health
#
# Disadvantages:
#
# * Possible pressure on shoulders and hips if not adjusted properly
# * May not be suitable for users with certain medical conditions, such as shoulder or hip injuries
#
# **Overall Sleep Quality Analysis:**
# Based on the combined sleep score of 3.06, the user's overall sleep quality can be classified as follows:
#
# Advantages:
#
# * Average sleep duration of 8 hours suggests a consistent sleep schedule
# * Low stress level (2) indicates a relatively calm and relaxed state before sleeping
# * High physical activity level (80) suggests regular exercise, which can help improve sleep quality
#
# Disadvantages:
#
# * The table-based predicted score is moderate at best (1.23 in Model 1 and 1.41 in Model 2), indicating some room for improvement
# * Some factors may be affecting the user's sleep quality, such as caffeine intake being zero (Model 2) but screen time being relatively high (5 hours)
#
# **Comprehensive Recommendations:**
# To further improve the user's sleep quality, I recommend the following:
#
# 1. **Establish a consistent sleep schedule:** Aim for 7-9 hours of sleep each night and try to maintain a consistent bedtime routine.
# 2. **Prioritize relaxation techniques:** Since the user has a low stress level, they may not need extensive relaxation techniques. However, incorporating activities like meditation, deep breathing, or yoga can help further reduce stress and improve sleep quality.
# 3. **Optimize sleep environment:** Ensure the bedroom is dark, quiet, and at a comfortable temperature (around 60-67°F/15-19°C). Invest in a supportive mattress and pillows to promote proper spinal alignment.
# 4. **Limit screen time before bed:** Aim for no more than 1 hour of screen time before bedtime to reduce blue light exposure and minimize stimulating activities.
# 5. **Incorporate relaxing pre-sleep habits:** Replace screen time with calming activities like reading, listening to music, or practicing gentle stretches.
# 6. **Monitor caffeine intake:** While the user's current intake is zero, it's essential to be mindful of caffeine consumption overall. Aim for moderate coffee and tea consumption (1-2 cups per day).
# 7. **Incorporate more physical activity:** Although the user has a high physical activity level, it's essential to maintain regular exercise routines, including activities that promote relaxation, such as yoga or walking.
# 8. **Consider sleep tracking:** Use apps like Fitbit, Apple Health, or dedicated sleep trackers to monitor sleep patterns and identify areas for improvement.
#
# By implementing these recommendations, the user can further optimize their sleep quality, leading to improved overall well-being and better performance in daily activities.
